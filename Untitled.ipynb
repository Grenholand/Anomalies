# %%
import pandas as pd
import numpy as np
from numpy import percentile
import datetime as dt
import matplotlib.pyplot as plt
plt.style.use({'figure.facecolor':'white'})
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest
from statsmodels.tsa.api import ExponentialSmoothing

# %%
df = pd.read_csv(r'C:/Users/egork/PycharmProjects/anomalies/data/dataset.csv', parse_dates=['datetime'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130511 entries, 0 to 130510
# Data columns (total 7 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   ou        130511 non-null  float64
#  1   datetime  130511 non-null  datetime64[ns]
#  2   cheques   130511 non-null  int64
#  3   rto       130511 non-null  float64
#  4   n_sku     130511 non-null  int64
#  5   cnt       130511 non-null  int64
#  6   cashnum   130511 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(4)
# memory usage: 7.0 MB

# %%
df.head()
# Out:
#       ou            datetime  cheques      rto  n_sku  cnt  cashnum
# 0  468.0 2019-11-16 08:00:00       34   8003.0    137  173        3
# 1  468.0 2019-11-16 09:00:00       40  20129.0    283  517        2
# 2  468.0 2019-11-16 10:00:00       41  15782.0    185  227        2
# 3  468.0 2019-11-16 11:00:00       63  39451.0    386  659        4
# 4  468.0 2019-11-16 12:00:00       84  57330.0    635  992        4

# %%
outliers_fraction = 0.05
ou = 471
c = 'cheques'

dd = df[df['ou']==ou]
dd = dd.set_index('datetime')

dd = dd[[c]].resample('D').sum()
dd = dd[:-5]
dd.head()
# Out:
#             cheques
# datetime
# 2019-11-16     2106
# 2019-11-17     2169
# 2019-11-18     2050
# 2019-11-19     1924
# 2019-11-20     2052

# %% [markdown]
# # Forecast

# %%
df_test = dd[-50:]
df_train = dd[:-50]

# %%
data = df_train[c]
data.index = pd.DatetimeIndex(data.index.values, freq='D')
data
# Out:
# 2019-11-16    2106
# 2019-11-17    2169
# 2019-11-18    2050
# 2019-11-19    1924
# 2019-11-20    2052
#               ...
# 2022-01-13    1696
# 2022-01-14    1810
# 2022-01-15    1775
# 2022-01-16    1737
# 2022-01-17    1685
# Freq: D, Name: cheques, Length: 794, dtype: int64

# %%
fit = ExponentialSmoothing(data, seasonal_periods=7, trend='add', seasonal='add').fit()

# %%
forecast = fit.forecast(50).to_frame().reset_index()
forecast.head()
# Out:
#        index            0
# 0 2022-01-18  1697.390725
# 1 2022-01-19  1716.876919
# 2 2022-01-20  1757.367008
# 3 2022-01-21  1839.202784
# 4 2022-01-22  1746.487446

# %%
forecast.rename(columns={'index':'datetime', 0:'forecast'}, inplace=True)
forecast.set_index('datetime', inplace=True)
forecast.head()
# Out:
#                forecast
# datetime
# 2022-01-18  1697.390725
# 2022-01-19  1716.876919
# 2022-01-20  1757.367008
# 2022-01-21  1839.202784
# 2022-01-22  1746.487446

# %%
fig ,ax = plt.subplots()
forecast.plot(ax =ax)
df_test.plot(ax=ax)
plt.show()

# %%
df_res = forecast.copy()
df_res['fact'] = df_test[c]
df_res['MAPE'] = abs(df_res.fact - df_res.forecast) / df_res.fact
df_res.head()
# Out:
#                forecast  fact      MAPE
# datetime
# 2022-01-18  1697.390725  1570  0.081141
# 2022-01-19  1716.876919  1621  0.059147
# 2022-01-20  1757.367008  1642  0.070260
# 2022-01-21  1839.202784  1799  0.022347
# 2022-01-22  1746.487446  1743  0.002001

# %%
threshold = percentile(df_res.MAPE, 90)
df_res['anomaly'] = df_res.MAPE > threshold
df_res.head()
# Out:
#                forecast  fact      MAPE  anomaly
# datetime
# 2022-01-18  1697.390725  1570  0.081141    False
# 2022-01-19  1716.876919  1621  0.059147    False
# 2022-01-20  1757.367008  1642  0.070260    False
# 2022-01-21  1839.202784  1799  0.022347    False
# 2022-01-22  1746.487446  1743  0.002001    False

# %% [markdown]
# ### Visualization

# %%
fig, ax = plt.subplots(figsize=(16, 9))
a = df_res.loc[df_res.anomaly, ['fact']]

ax.plot(df_res.index, df_res.fact)
ax.scatter(a.index, a.fact, color='red')
plt.show()

# %% [markdown]
# ### Isolation Forest

# %%
scaler = StandardScaler()
np_scaled = scaler.fit_transform(dd.values.reshape(-1,1))
data = pd.DataFrame(np_scaled)

data.head()
# Out:
#           0
# 0  0.898325
# 1  1.139273
# 2  0.684149
# 3  0.202254
# 4  0.691798

# %%
model = IsolationForest(contamination=0.05)
model.fit(data)
# Out:
# IsolationForest(contamination=0.05)

# %%
dd['anomaly'] = model.predict(data)
dd.head()
# Out:
#             cheques  anomaly
# datetime
# 2019-11-16     2106        1
# 2019-11-17     2169        1
# 2019-11-18     2050        1
# 2019-11-19     1924        1
# 2019-11-20     2052        1

# %%
fig, ax = plt.subplots(figsize=(16, 9))
a = dd.loc[dd.anomaly == -1, [c]]

ax.plot(dd.index, dd[c])
ax.scatter(a.index, a[c], color='red')
plt.show()
